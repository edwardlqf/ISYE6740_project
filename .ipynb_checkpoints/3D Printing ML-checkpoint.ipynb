# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import os
from matplotlib.pyplot import imshow
import tensorly as tl
from tensorly.regression.tucker_regression import TuckerRegressor
from tensorly.base import tensor_to_vec, partial_tensor_to_vec
from skimage import color

# %%
import matplotlib as mpl
mpl.rc("savefig", dpi=100) # Adjust for higher-resolution figures

# %%
def read_img(path):
    """
    Read image and store it as an array, given the image path. 
    Returns the 3 dimensional image array.
    """
    img = Image.open(path)
    img_arr = np.array(img, dtype='int32')
    img.close()
    return img_arr

def display_image(arr):
    """
    display the image
    input : 3 dimensional array
    """
    arr = arr.astype(dtype='uint8')
    img = Image.fromarray(arr, 'RGB')
    imshow(np.asarray(img))

# %%
working_dir = r'C:\Users\Edward\Documents\DonationCoder\AutomaticScreenshotter\Screenshots\2020\11\23'

# %%
l = len([name for name in os.listdir(working_dir)])

img_arr = np.zeros((l,690,1220,3))

for i, filename in enumerate(os.listdir(working_dir)):
    #print(filename)
    img = read_img(working_dir + '\\' + filename)
    img_arr[i] = img[180:-170,100:-600,:]

# %%
plt.imshow(img_arr[7].astype(np.uint8))

# %%
(color.rgb2gray(img_arr[0:10])).shape
# Out:
# (10, 690, 1220)

# %% [markdown]
# we have 28 images, take batchs of 10 images and create a image tensor, in greyscale

# %%
img_tens = np.zeros((l-10,10,690,1220))

for i in range(l-10):
    img_tens[i][i:10] = img_arr[i:10]
